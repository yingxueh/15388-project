# %%
import pandas as pd
import numpy as np
import seaborn

# %%
from google.colab import files
import io
uploaded = files.upload()
data = pd.read_csv(io.BytesIO(uploaded["all.csv"]), header = 0)

# y : Price
# x : Beds, Baths, Sqft, YearBuilt, WalkScore, TransitScore, ParkingPrice, PropertyType, ParkingType, Cooling, Laundry

# %%
# y variable
seaborn.histplot(data["Price"], bins = 20)

# %%
data["Beds"].unique()
# Out:
# array([ 1.,  2.,  0.,  3.,  4., -1.,  6.,  5.])

# %%
# Beds
seaborn.countplot(x = "Beds", data = data)

# %%
# Baths
seaborn.countplot(x = "Baths", data = data)

# %%
# Sqft
seaborn.histplot(data["Sqft"], bins = 15)

# %%
# YearBuilt
seaborn.histplot(data["YearBuilt"], bins = 10)

# %%
# WalkScore
seaborn.histplot(data["WalkScore"], bins = 10)

# %%
# TransitScore
seaborn.histplot(data["TransitScore"], bins = 10)

# %%
# ParkingPrice
seaborn.histplot(data["ParkingPrice"], bins = 10)

# %%
# PropertyType
seaborn.countplot(x = "PropertyType", data = data)

# %%
# ParkingType
seaborn.countplot(x = "ParkingType", data = data)

# %%
# Cooling
seaborn.countplot(x = "Cooling", data = data)

# %%
# Laundry
seaborn.countplot(x = "Laundry", data = data)

# %%
# Sqft vs. Price
seaborn.scatterplot(x = 'Sqft', y = 'Price', data = data)

# %%
# YearBuilt vs. Price
seaborn.scatterplot(x = 'YearBuilt', y = 'Price', data = data)

# %%
# WalkScore vs. Price
seaborn.scatterplot(x = 'WalkScore', y = 'Price', data = data)

# %%
# TransitScore vs. Price
seaborn.scatterplot(x = 'TransitScore', y = 'Price', data = data)

# %%
# ParkingPrice vs. Price
seaborn.scatterplot(x = 'ParkingPrice', y = 'Price', data = data)

# %%
# Beds vs Price
seaborn.boxplot(x = 'Beds', y = 'Price', data = data)

# %%
# Baths vs Price
seaborn.boxplot(x = 'Baths', y = 'Price', data = data)

# %%
# PropertyType vs Price
seaborn.boxplot(x = 'PropertyType', y = 'Price', data = data)

# %%
# ParkingType vs Price
seaborn.boxplot(x = 'ParkingType', y = 'Price', data = data)

# %%
# Cooling vs Price
seaborn.boxplot(x = 'Cooling', y = 'Price', data = data)

# %%
# Laundry vs Price
seaborn.boxplot(x = 'Laundry', y = 'Price', data = data)
